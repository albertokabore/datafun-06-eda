# %% [markdown]
# Albert Kabore

# %% [markdown]
# # Penguins Exploratory Dataset Analysis

# %% [markdown]
# Introduction
#
# In this exploratory Data analysis, we examine a dataset featuring measurements of three penguin species: Adelie, Chinstrap, and Gentoo. The dataset includes features such as bill length, bill depth, flipper length, body mass, and the island of observation. Through exploratory Data analysis, we aim to uncover insights about these species.

# %% [markdown]
# # Overview

# %% [markdown]
# Project 6 is an opportunity to create your own custom exploratory data analysis (EDA) project using GitHub, Git, Jupyter, pandas, Seaborn and other popular data analytics tools.

# %% [markdown]
# Import Dependencies (At the Top, After the Introduction)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# Exploratory Data Analysis

# %% [markdown]
# # Step 1. Data Acquisition

# %%
# Load the dataset into a pandas DataFrame - adjust this process for your custom data
df = sns.load_dataset("penguins")

# %%
# Inspect first rows of the DataFrame
print(df.head())
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# # Step 2. Initial Data Inspection

# %% [markdown]
# Check the shape

# %%
print(df.head(10))
print(df.shape)
print(df.dtypes)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
# 6  Adelie  Torgersen            38.9           17.8              181.0
# 7  Adelie  Torgersen            39.2           19.6              195.0
# 8  Adelie  Torgersen            34.1           18.1              193.0
# 9  Adelie  Torgersen            42.0           20.2              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female
# 5       3650.0    Male
# ...

# %% [markdown]
# # Step 3. Initial Descriptive Statistics

# %%
print(df.describe())
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %% [markdown]
# Observation:
#
# The dataset contains 342 samples for each measurement: bill_length_mm, bill_depth_mm, flipper_length_mm, and body_mass_g.
#
# Bill Length:
#
# •	Mean: 43.92 mm
#
# •	Standard Deviation: 5.46 mm
#
# •	Range: 32.1 to 59.6 mm
#
# Bill Depth:
#
# •	Mean: 17.15 mm
#
# •	Standard Deviation: 1.97 mm
#
# •	Range: 13.1 to 21.5 mm
#
# Flipper Length:
#
# •	Mean: 200.92 mm
#
# •	Standard Deviation: 14.06 mm
#
# •	Range: 172 to 231 mm
#
# Body Mass:
#
# •	Mean: 4201.75 g
#
# •	Standard Deviation: 801.95 g
#
# •	Range: 2700 to 6300 g
#
# The data shows significant variability, especially in body mass and flipper length.

# %% [markdown]
# # Step 4. Initial Data Distribution for Numerical Columns

# %%
# Inspect histogram by numerical column
df['body_mass_g'].hist()
# Inspect histograms for all numerical columns
df.hist()
# Show all plots
plt.show()

# %% [markdown]
# Observation:
#
# Body Mass Distribution:
#
# •	The histogram shows a right-skewed distribution.
#
# •	The majority of body mass values fall between 3000 and 5000 grams.
#
# •	There is a peak around 3500 grams, indicating a higher frequency in this range.
#
# Bill Length Distribution:
#
# •	Bill length values range from 32.1 to 59.6 mm.
#
# •	The histogram shows a bimodal distribution with peaks around 40 mm and 50 mm.
#
# •	Most penguins have bill lengths between 35 mm and 50 mm.
#
# Bill Depth Distribution:
#
# •	Bill depth values range from 13.1 to 21.5 mm.
#
# •	The histogram is relatively symmetrical with a peak around 18 mm.
#
# •	Most penguins have bill depths between 16 mm and 20 mm.
#
# Flipper Length Distribution:
#
# •	Flipper length values range from 172 to 231 mm.
#
# •	The histogram shows a trimodal distribution with peaks around 180 mm, 195 mm, and 215 mm.
#
# •	Most penguins have flipper lengths between 180 mm and 220 mm.
#
# These histograms highlight the diversity in physical characteristics within the penguin dataset, essential for distinguishing between different species.

# %% [markdown]
# # Step 5. Initial Data Distribution for Categorical Columns

# %% [markdown]
# Choose a categorical column and use df['column_name'].value_counts() to display the count of each category. Use a loop to show the value counts for all categorical columns. For example:

# %%
# Inspect value counts by categorical column
df['species'].value_counts()

# Inspect value counts for all categorical columns
for col in df.select_dtypes(include=['object', 'category']).columns:
    # Display count plot
    sns.countplot(x=col, data=df)
    plt.title(f'Distribution of {col}')
    plt.show()

# Show all plots
plt.show()

# %% [markdown]
# Observations:
#
# Distribution of Species:
#
# •	Adelie penguins are the most abundant species in the dataset, with over 140 samples.
#
# •	Gentoo penguins have around 120 samples, making them the second most abundant species.
#
# •	Chinstrap penguins are the least represented, with around 70 samples.
#
# Distribution of Island:
#
# •	Biscoe island has the highest number of penguins, with over 160 samples.
#
# •	Dream island has the second highest number, with around 120 samples.
#
# •	Torgersen island has the fewest penguins, with around 40 samples.
#
# Distribution of Sex:
#
# •	The dataset is balanced in terms of sex distribution, with nearly equal numbers of male and female penguins.
#
# •	Both male and female penguins have around 160 samples each.
#
# These visualizations highlight the distribution of different penguin species, their geographical locations on various islands, and the balanced representation of sexes within the dataset. This information is crucial for understanding the diversity and distribution patterns within the penguin population.

# %% [markdown]
# # 6. Initial Data Preparation (or Data Preprocessing)

# %% [markdown]
# 1. Renaming a Column

# %%
# Renaming a column
df.rename(columns={'species': 'Penguin Species'}, inplace=True)

# %%
# Verify transformations
print(df.head())
# Out:
#   Penguin Species     island  bill_length_mm  bill_depth_mm  \
# 0          Adelie  Torgersen            39.1           18.7
# 1          Adelie  Torgersen            39.5           17.4
# 2          Adelie  Torgersen            40.3           18.0
# 3          Adelie  Torgersen             NaN            NaN
# 4          Adelie  Torgersen            36.7           19.3
#
#    flipper_length_mm  body_mass_g     sex
# 0              181.0       3750.0    Male
# 1              186.0       3800.0  Female
# 2              195.0       3250.0  Female
# 3                NaN          NaN     NaN
# 4              193.0       3450.0  Female

# %% [markdown]
# Observations:
#
# •	The dataset contains measurements for different penguin species.
#
# •	Bill Length: Ranges from approximately 32.1 to 59.6 mm, with peaks around 40 mm and 50 mm.
#
# •	Bill Depth: Symmetrical distribution around 18 mm, ranging from 13.1 to 21.5 mm.
#
# •	Flipper Length: Trimodal distribution with peaks around 180 mm, 195 mm, and 215 mm, ranging from 172 to 231 mm.
#
# •	Body Mass: Right-skewed distribution, primarily between 3000 and 5000 grams, with peaks around 3500 and 4000 grams.
#
# •	The data includes some missing values for bill length, bill depth, flipper length, and body mass.
#
# •	Measurements vary significantly, indicating diverse physical characteristics across penguin species.

# %% [markdown]
# 2. Adding New Columns.

# %%
# Adding a new column
df['body_mass_lbs'] = df['body_mass_g'] * 0.00220462

# %%
# Verify transformations
print(df.head())
# Out:
#   Penguin Species     island  bill_length_mm  bill_depth_mm  \
# 0          Adelie  Torgersen            39.1           18.7
# 1          Adelie  Torgersen            39.5           17.4
# 2          Adelie  Torgersen            40.3           18.0
# 3          Adelie  Torgersen             NaN            NaN
# 4          Adelie  Torgersen            36.7           19.3
#
#    flipper_length_mm  body_mass_g     sex  body_mass_lbs
# 0              181.0       3750.0    Male       8.267325
# 1              186.0       3800.0  Female       8.377556
# 2              195.0       3250.0  Female       7.165015
# 3                NaN          NaN     NaN            NaN
# 4              193.0       3450.0  Female       7.605939

# %% [markdown]
# Observation:
#
# New Column Added: 'body_mass_lbs' is added, converting body mass from grams to pounds.
#
# Penguin Species: Includes species such as Adelie.
#
# Measurements:
#
# •	Bill Length: Values range around 36.7 to 40.3 mm in the sample.
#
# •	Bill Depth: Values range around 17.4 to 19.3 mm in the sample.
#
# •	Flipper Length: Values range around 181 to 195 mm in the sample.
#
# •	Body Mass: Ranges from 3250 to 3800 grams.
#
# Body Mass in Pounds: Calculated values range from approximately 7.17 to 8.38 lbs.
# Missing Values: Present in bill measurements, flipper length, body mass, and sex for some entries.

# %%
# Display the updated DataFrame with the new column
print(df.head(10))
# Out:
#   Penguin Species     island  bill_length_mm  bill_depth_mm  \
# 0          Adelie  Torgersen            39.1           18.7
# 1          Adelie  Torgersen            39.5           17.4
# 2          Adelie  Torgersen            40.3           18.0
# 3          Adelie  Torgersen             NaN            NaN
# 4          Adelie  Torgersen            36.7           19.3
# 5          Adelie  Torgersen            39.3           20.6
# 6          Adelie  Torgersen            38.9           17.8
# 7          Adelie  Torgersen            39.2           19.6
# 8          Adelie  Torgersen            34.1           18.1
# 9          Adelie  Torgersen            42.0           20.2
#
#    flipper_length_mm  body_mass_g     sex  body_mass_lbs
# 0              181.0       3750.0    Male       8.267325
# 1              186.0       3800.0  Female       8.377556
# 2              195.0       3250.0  Female       7.165015
# 3                NaN          NaN     NaN            NaN
# ...

# %% [markdown]
# # Step 7. Initial Visualizations

# %% [markdown]
# Subsection 1: Exploring the Relationship Between Flipper Length and Body Mass

# %% [markdown]
# Goal:
# Investigate how flipper length correlates with body mass across different penguin species.

# %% [markdown]
# Chart Type: Scatter Plot

# %%
# Scatter plot of flipper length vs. body mass
plt.figure(figsize=(10, 6))
scatter_plot = sns.scatterplot(data=df, x="flipper_length_mm", y="body_mass_g", hue="Penguin Species")
scatter_plot.set_xlabel("Flipper Length (mm)")
scatter_plot.set_ylabel("Body Mass (g)")
scatter_plot.set_title("Penguin Flipper Length vs. Body Mass")
plt.show()

# %% [markdown]
# Observation:
#
# The scatter plot above illustrates the relationship between flipper length and body mass across different penguin species. We can observe distinct clusters for each species, suggesting a correlation between these two features. For instance, the Gentoo species generally has larger body mass and longer flippers compared to Adelie and Chinstrap. This visual insight indicates that flipper length could be a good predictor of body mass and potentially useful for species classification.
#
# Positive Correlation:
#
# •	There is a positive correlation between flipper length and body mass for all penguin species.
#
# Species Clustering:
#
# •	Gentoo penguins generally have longer flippers and higher body mass compared to Adelie and Chinstrap penguins.
#
# •	Adelie and Chinstrap penguins show more overlap but still form distinct clusters.
#
# Range of Values:
#
# •	Flipper lengths range from 170 mm to 230 mm.
#
# •	Body mass ranges from 3000 g to over 6000 g.
#
# Gentoo Penguins:
#
# •	Gentoo penguins exhibit a wider range of body mass and flipper lengths, often exceeding 5000 g in body mass and 220 mm in flipper length.
#
# This scatter plot effectively illustrates the relationship between flipper length and body mass, highlighting species-specific characteristics and clustering.

# %% [markdown]
# Chart Type: Regression Plot

# %%
# Regression plot of flipper length vs. body mass
plt.figure(figsize=(10, 6))
reg_plot = sns.lmplot(data=df, x="flipper_length_mm", y="body_mass_g", hue="Penguin Species", height=6, aspect=1.5)
plt.xlabel("Flipper Length (mm)")
plt.ylabel("Body Mass (g)")
plt.title("Regression of Flipper Length vs. Body Mass by Penguin Species")
plt.show()

# %% [markdown]
# Observation:
#
# The regression plot displays the linear relationship between flipper length and body mass across different penguin species. We see that all three species show a positive correlation, with Gentoo penguins generally having higher body mass and longer flippers. This plot helps in understanding how these two variables are related and emphasizes the differences among species.

# %% [markdown]
# Subsection 2: Comparing Bill Length Across Penguin Species

# %% [markdown]
# Goal: Compare the distribution of bill lengths among the different penguin species.

# %% [markdown]
# Chart Type: Box Plot

# %%
# Box plot for bill length
plt.figure(figsize=(10, 6))
box_plot = sns.boxplot(data=df, x="Penguin Species", y="bill_length_mm", hue="Penguin Species", palette="viridis", dodge=False)
box_plot.set_xlabel("Penguin Species")
box_plot.set_ylabel("Bill Length (mm)")
box_plot.set_title("Distribution of Bill Length by Penguin Species")
plt.legend([],[], frameon=False)  # Removes the legend since we are only using hue for color
plt.show()

# %% [markdown]
# Observation:
#
# The box plot shows the distribution of bill lengths for the three penguin species. We can see that the Gentoo species tends to have longer bills compared to Adelie and Chinstrap. The median bill length is highest for Gentoo, followed by Chinstrap, and then Adelie. The variability in bill length is also evident, with Gentoo displaying the widest range. This visualization helps us understand the physical differences between species, particularly in bill length.

# %% [markdown]
# Subsection 3: Distribution of Body Mass Across Penguin Species

# %% [markdown]
# Goal: Examine the distribution of body mass for each penguin species.

# %% [markdown]
# Chart Type: Violin Plot

# %%
# Violin plot for body mass
plt.figure(figsize=(10, 6))
violin_plot = sns.violinplot(data=df, x="Penguin Species", y="body_mass_g", hue="Penguin Species", palette="muted", dodge=False)
violin_plot.set_xlabel("Penguin Species")
violin_plot.set_ylabel("Body Mass (g)")
violin_plot.set_title("Distribution of Body Mass by Penguin Species")
plt.legend([],[], frameon=False)  # Removes the legend since we are only using hue for color
plt.show()

# %% [markdown]
# Observations:
#
# •	Body Mass Distribution:
#
# •	Gentoo penguins generally have higher body mass compared to Adelie and Chinstrap penguins.
#
# •	The median body mass of Gentoo penguins is around 5000 grams.
#
# •	Adelie and Chinstrap penguins have similar median body masses, around 3750 grams.
#
# Range of Values:
#
# •	Gentoo penguins show a wider range of body mass values, from approximately 3500 to 6000 grams.
#
# •	Adelie and Chinstrap penguins exhibit narrower body mass distributions, ranging from about 3000 to 5000 grams.
#
# Shape of Distributions:
#
# •	The violin plot for Gentoo penguins is more spread out, indicating higher variability in body mass.
#
# •	Adelie and Chinstrap penguins have more compact distributions with fewer extreme values.
#
# Species Differentiation:
#
# •	The distinct separation in body mass distributions among the three species highlights the morphological differences and aids in species identification.

# %% [markdown]
# Subsection 4: Pairwise Relationships in the Penguin Dataset

# %% [markdown]
# Goal: Visualize pairwise relationships and distributions for numerical features in the dataset, separated by species.

# %% [markdown]
# Chart Type: Pair Plot

# %%
# Pair plot for numerical features
pair_plot = sns.pairplot(df, hue="Penguin Species", diag_kind="kde", markers=["o", "s", "D"])
pair_plot.fig.suptitle("Pairwise Relationships in the Penguin Dataset", y=1.02)
plt.show()

# %% [markdown]
# Observation:
#
# Bill Length vs. Bill Depth:
#
# •	Gentoo penguins generally have longer bills and shallower depths compared to Adelie and Chinstrap penguins.
#
# •	Distinct clustering is observed for each species.
#
# Flipper Length vs. Body Mass:
#
# •	There is a strong positive correlation between flipper length and body mass.
#
# •	Gentoo penguins have longer flippers and higher body mass compared to the other species.
#
# Body Mass:
#
# •	Gentoo penguins tend to have a higher body mass, followed by Chinstrap and Adelie penguins.
#
# •	The distribution of body mass is more spread out for Gentoo penguins.
#
# Flipper Length:
#
# •	The flipper length distribution shows that Gentoo penguins have significantly longer flippers.
#
# •	Adelie and Chinstrap penguins show overlapping but distinct distributions.
# Pairwise Relationships:
#
# •	Strong correlations are evident in pairs involving body mass and flipper length.
#
# •	The addition of body_mass_lbs shows a perfect correlation with body_mass_g, as expected.
#
# Species Differentiation:
#
# •	The pair plot effectively differentiates the species based on multiple features, with clear separation for Gentoo penguins and more overlap between Adelie and Chinstrap penguins.
#
# These insights help in understanding the morphological differences among the penguin species and can aid in species classification.

# %% [markdown]
# Subsection 5: Correlation Matrix of Penguin Features

# %% [markdown]
# Goal: Examine the correlations between different numerical features in the dataset.

# %% [markdown]
# Chart Type: Heatmap

# %%
# Compute the correlation matrix for numerical columns
numerical_df = df.select_dtypes(include=['float64', 'int64'])
corr = numerical_df.corr()

# Heatmap of the correlation matrix
plt.figure(figsize=(8, 6))
heatmap = sns.heatmap(corr, annot=True, cmap="coolwarm", center=0)
heatmap.set_title("Correlation Matrix of Penguin Features")
plt.show()

# %% [markdown]
# Observation:
#
# Positive Correlations:
#
# •	Flipper Length and Body Mass: There is a strong positive correlation (0.87) between flipper length and body mass, indicating that penguins with longer flippers tend to have higher body mass.
#
# •	Bill Length and Flipper Length: Bill length and flipper length also show a significant positive correlation (0.66).
#
# Negative Correlations:
#
# •	Bill Depth and Flipper Length: A moderate negative correlation (-0.58) exists between bill depth and flipper length, suggesting that penguins with deeper bills tend to have shorter flippers.
#
# Bill Length and Body Mass:
#
# •	Moderate positive correlations are observed between bill length and body mass (0.6), indicating that penguins with longer bills generally have higher body mass.
#
# Bill Depth:
#
# •	Bill depth shows a moderate negative correlation with both flipper length (-0.58) and body mass (-0.47), indicating an inverse relationship with these features.
#
# Body Mass in Pounds:
#
# •	The correlation matrix confirms that body mass in pounds has a perfect correlation (1.0) with body mass in grams, as expected from the linear conversion.
#
# These observations highlight key relationships between different morphological features of penguins, which can be useful for further analysis and predictive modeling.

# %% [markdown]
# Subsection 6: Bill Length and Depth Distribution

# %% [markdown]
# Goal: To explore the distribution of bill length and bill depth across different penguin species.

# %% [markdown]
# Chart Type: Joint Plot

# %%
# Joint plot for bill length vs. bill depth
plt.figure(figsize=(10, 6))
joint_plot = sns.jointplot(data=df, x="bill_length_mm", y="bill_depth_mm", hue="Penguin Species", kind="kde", height=8)
plt.xlabel("Bill Length (mm)")
plt.ylabel("Bill Depth (mm)")
plt.suptitle("Joint Distribution of Bill Length and Depth by Penguin Species", y=1.02)
plt.show()

# %% [markdown]
# Observation:
# The count plot shows the distribution of different penguin species across various islands. We can observe that the Adelie species is present on all three islands, while Chinstrap penguins are found only on Dream island. Gentoo penguins are predominantly on Biscoe island. This visualization helps in understanding the geographical distribution of penguin species and can be useful for ecological studies.

# %% [markdown]
# # Step 8. Initial Storytelling

# %% [markdown]
# Conclusion:
#
# Through this exploratory data analysis, we've gained valuable insights into the morphological differences and distribution patterns of penguin species. The visualizations highlighted key relationships between features like flipper length and body mass, and the correlation matrix helped quantify these relationships. These findings can guide further analysis, such as predictive modeling or ecological studies, to better understand the characteristics and behaviors of these fascinating birds.
